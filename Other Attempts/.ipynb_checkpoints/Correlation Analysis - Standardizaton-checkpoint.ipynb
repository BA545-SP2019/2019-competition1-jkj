# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import seaborn as sns
from string import ascii_letters

# %%
stand_df = pd.read_csv('StandDF', index_col=0)
stand_df.head()
# Out:
#      I1                                  I2    I3    P(IPO)      P(H)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674 -0.636323 -0.905198
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834 -0.968157 -0.829439
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834 -1.134074 -0.223360
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834 -0.387448  0.079679
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  1.188763  0.837277
#
#        P(L)   P(1Day)        C1        C2        C3    ...          C3'  \
# 0 -0.865043 -0.190333 -0.175193  0.397360  0.010968    ...     0.942972
# 1 -0.951417 -0.254485  0.735662 -2.516611 -0.020955    ...    -1.060477
# 2 -0.260419 -0.262122 -0.387947  0.397360 -0.018553    ...    -1.060477
# 3  0.085080 -0.183112  0.403233  0.397360 -0.016467    ...    -1.060477
# 4  0.948829  0.430778 -0.454433  0.397360 -0.010272    ...     0.942972
#
#         C5'    P(mid)       C6'       T4'       T3'       T5'       S1'  \
# 0 -0.121925 -0.888512  0.541241  0.112962 -0.559157 -0.383993  0.785296
# 1  1.186213 -0.888512 -0.490559  0.026829  0.053878 -0.027744  0.010247
# 2 -0.201269 -0.241240 -0.490559  0.023381  0.050960 -0.029416  0.013524
# 3 -0.212395  0.082395 -0.490559  0.045988  0.047121 -0.039578 -0.003129
# 4 -0.144048  0.891485 -0.026249 -0.000528  0.048306 -0.059095  0.005731
#
#         S2'       S3'
# 0  0.149560  0.203780
# 1  0.015851 -0.012833
# 2  0.012059 -0.011125
# 3  0.016015 -0.016718
# 4  0.016783 -0.012009
#
# [5 rows x 34 columns]

# %%
#Calculate correlation with .corr(): 
print(stand_df.corr(method = 'spearman'))
# Out:
#            P(IPO)      P(H)      P(L)   P(1Day)        C1        C2        C3  \
# P(IPO)   1.000000  0.803705  0.805593  0.647840 -0.068953  0.268853  0.175611
# P(H)     0.803705  1.000000  0.996178  0.444217 -0.065231  0.280728  0.141659
# P(L)     0.805593  0.996178  1.000000  0.447109 -0.062057  0.291564  0.145824
# P(1Day)  0.647840  0.444217  0.447109  1.000000 -0.035852  0.234564  0.045517
# C1      -0.068953 -0.065231 -0.062057 -0.035852  1.000000 -0.000488  0.046093
# C2       0.268853  0.280728  0.291564  0.234564 -0.000488  1.000000  0.015888
# C3       0.175611  0.141659  0.145824  0.045517  0.046093  0.015888  1.000000
# C4      -0.004493 -0.041148 -0.045253  0.002386  0.091500 -0.031415  0.014531
# C5       0.358363  0.375942  0.380110  0.216681  0.050327  0.432822  0.133456
# C6       0.396868  0.448986  0.455252  0.194187  0.002105  0.401304  0.167353
# C7       0.407719  0.496943  0.499369  0.159160  0.069115  0.210420  0.341290
# T1       0.274026  0.295533  0.300869  0.099934  0.141133  0.207737  0.125257
# T2       0.242433  0.277535  0.283039  0.101614  0.140769  0.204534  0.110517
# T3       0.227775  0.267644  0.273008  0.088497  0.151147  0.204339  0.108054
# T4       0.250454  0.281695  0.287372  0.101145  0.132520  0.210689  0.123982
# T5       0.204004  0.252838  0.258739  0.071640  0.163068  0.238000  0.046245
# P(mid)   0.062931 -0.034163  0.034013 -0.031513 -0.015810  0.015244 -0.026734
# C6'      1.000000  0.020926  0.011227  0.046120  0.037454  0.005108  0.038281
# T4'      0.020926  1.000000 -0.051693 -0.098278  0.016079 -0.016975 -0.101406
# T3'      0.011227 -0.051693  1.000000  0.372426  0.123278  0.031319  0.278949
# T5'      0.046120 -0.098278  0.372426  1.000000  0.184738  0.187909  0.343177
# S1'      0.037454  0.016079  0.123278  0.184738  1.000000  0.183719  0.168302
# S2'      0.005108 -0.016975  0.031319  0.187909  0.183719  1.000000  0.196332
# S3'      0.038281 -0.101406  0.278949  0.343177  0.168302  0.196332  1.000000
#
# [31 rows x 31 columns]

# %%
# Compute the correlation matrix
corr = stand_df.corr(method = 'spearman')

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.set(style="white")

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Set up the matplotlib figure
ax = plt.subplots(figsize=(11, 9))

# Draw the heatmap with the mask and aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax= 1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
#Sort out the top correlation values using Spearman method 
def correl(stand_df):
    cor = stand_df.corr(method = 'spearman')
    corrm = np.corrcoef(stand_df.transpose())
    corr = corrm - np.diagflat(corrm.diagonal())
    
   ##Print max and min correlation values 
    print("max corr:",corr.max(), ", min corr: ", corr.min())
    
    ## Drop duplicates, sort values in decending order, and include all values not equal to 1
    cor3 = cor.stack().sort_values(ascending=False).drop_duplicates()
    high_cor = cor3[cor3.values!=1]
    
    
    ## Display threshold above 0.5 for highly correlated results        
    threshold = 0.5
    display(high_cor[high_cor>threshold])
correl(corr)
# Out:
# max corr: 0.9999840972291217 , min corr:  -0.971027281588594
# T3       T4         0.998790
# P(L)     P(mid)     0.998387
# T3       T2         0.997984
# P(H)     P(L)       0.996774
# T4       T2         0.996371
#          T1         0.995968
# T3       T1         0.995161
# T2       T1         0.993145
# S3       T5         0.989919
# T3       T5         0.985484
# T5       T2         0.983871
# T4       T5         0.981855
# T5       S2         0.979032
# T3       S3         0.978226
# T2       S3         0.976613
# T5       T1         0.976210
# S1       T3         0.973387
# T3       S2         0.972581
# S2       T2         0.971371
# T2       S1         0.970565
# S1       T4         0.970161
#          T1         0.969355
# T5       S1         0.968952
# S2       T1         0.967339
#          T4         0.966129
# S3       S2         0.962903
# S1       S2         0.961290
# S3       S1         0.958871
# P(IPO)   P(L)       0.935887
#          P(H)       0.935081
#                       ...
# C1       S1         0.578629
# C5'      S3         0.575000
# T4       C5'        0.565726
# C1       T3         0.564516
# C5'      T2         0.562500
# C1       T2         0.560081
# T2       P(IPO)     0.559677
# T3       C5'        0.558065
# T4       C1         0.557661
#          P(IPO)     0.555242
# S1       C3         0.554839
# C5'      T1         0.553629
# P(IPO)   T3         0.553226
# P(1Day)  C3'        0.552419
# T1       C3         0.542742
# T5       C5'        0.541935
# C2       C3         0.540726
# S1'      Y2         0.539919
# C3'      S1         0.535081
# P(1Day)  C5         0.534677
# T3       C3         0.531048
# C3'      T1         0.522581
# T2       C3'        0.516532
# C3'      T4         0.514516
# T3       C3'        0.511694
# P(IPO)   T5         0.510081
# C7       P(1Day)    0.508871
# C3       C5         0.508468
# C3'      C5         0.507258
# P(1Day)  C3         0.506048
# Length: 161, dtype: float64

# %%
#Sort out the low correlation values using Spearman method 
def correl(stand_df):
    cor = stand_df.corr(method = 'spearman')
    corrm = np.corrcoef(stand_df.transpose())
    corr = corrm - np.diagflat(corrm.diagonal())
    
    ##Print max and min correlation values 
    print("max corr:",corr.max(), ", min corr: ", corr.min())
    
    ## Drop duplicates, sort values in decending order, and include all values not equal to -1
    cor3 = cor.stack().sort_values(ascending=False).drop_duplicates()
    low_cor = cor3[cor3.values!=-1]
    
    ## Display threshold below -0.5 for highly correlated results      
    threshold = -0.5
    display(low_cor[low_cor<threshold])
correl(corr)
# Out:
# max corr: 0.9999840972291217 , min corr:  -0.971027281588594
# S3'      T4'   -0.503226
# C6       Y2    -0.522581
# C2       S3'   -0.523387
# T5'      C1    -0.528629
# C7       Y2    -0.543145
# T5'      C6    -0.553226
# C5       S3'   -0.556452
# T4'      T5'   -0.560081
# C2       S1'   -0.560484
# S2'      T4'   -0.562097
# Y2       T2    -0.566935
#          Y1    -0.574194
# T4       Y2    -0.575806
# Y2       T3    -0.579435
# P(1Day)  Y1    -0.584274
# S2       S3'   -0.585081
# Y2       T1    -0.589516
# S1'      C6    -0.589919
# C1       S1'   -0.592742
# T2       S3'   -0.598790
# S3'      T3    -0.604839
# T5       Y2    -0.608065
# T4       S3'   -0.610081
# T1       S3'   -0.610887
# S2'      C5'   -0.619758
# T5'      C2    -0.627823
# C5'      T5'   -0.628629
# T5       S3'   -0.632661
# S1       Y2    -0.633871
# S3       S3'   -0.650000
# C5       S1'   -0.663710
# S2       Y2    -0.670565
# S1       S3'   -0.671774
# C1       S2'   -0.672984
# S2'      C5    -0.695161
# S2       S2'   -0.728629
# S2'      T5    -0.747581
# S3       S2'   -0.760887
# S2'      T3    -0.765726
# T4       S2'   -0.766532
# T2       S2'   -0.769758
# C5       T5'   -0.772984
# T5'      S2    -0.775000
# S1'      T4    -0.776210
#          T3    -0.783065
# T5'      T1    -0.788306
#          S1    -0.788710
#          T3    -0.789113
# T2       S1'   -0.789516
# T5'      T2    -0.791532
# S1       S2'   -0.792339
# T4       T5'   -0.793952
# T5       T5'   -0.823387
# S2       S1'   -0.825806
# T5       S1'   -0.830645
# S3       S1'   -0.838710
# S1       S1'   -0.839919
# S3       T5'   -0.842339
# C6'      Y1    -0.847984
# dtype: float64

# %%
##Create a new DF from stand_df excluding columns T and S columns, added ratio equivalents
new_df = pd.read_csv('StandDF', index_col=0, usecols=['I1','I2','I3','P(IPO)','P(H)','P(L)','P(1Day)','C1','C2','C3',
                                                     'C4','C5','C6','C7','Y1','Y2',"C3'","C5'","C6'","T4'","T3'","T5'","S1'","S2'","S3'" ])
new_df.head()
# Out:
#                                       I2    I3    P(IPO)      P(H)      P(L)  \
# I1
# AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674 -0.636323 -0.905198 -0.865043
# ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834 -0.968157 -0.829439 -0.951417
# ACAD          ACADIA PHARMACEUTICALS INC  2834 -1.134074 -0.223360 -0.260419
# ACHN       ACHILLION PHARMACEUTICALS INC  2834 -0.387448  0.079679  0.085080
# ACLI     AMERICAN COMMERCIAL LINES INC.   4492  1.188763  0.837277  0.948829
#
#        P(1Day)        C1        C2        C3        C4    ...           Y2  \
# I1                                                        ...
# AATI -0.190333 -0.175193  0.397360  0.010968  0.663539    ...     0.648717
# ABPI -0.254485  0.735662 -2.516611 -0.020955 -0.631805    ...    -1.541505
# ACAD -0.262122 -0.387947  0.397360 -0.018553  0.408314    ...    -1.541505
# ACHN -0.183112  0.403233  0.397360 -0.016467  0.387190    ...     0.648717
# ACLI  0.430778 -0.454433  0.397360 -0.010272 -1.289555    ...     0.648717
#
#            C3'       C5'       C6'       T4'       T3'       T5'       S1'  \
# I1
# AATI  0.942972 -0.121925  0.541241  0.112962 -0.559157 -0.383993  0.785296
# ABPI -1.060477  1.186213 -0.490559  0.026829  0.053878 -0.027744  0.010247
# ACAD -1.060477 -0.201269 -0.490559  0.023381  0.050960 -0.029416  0.013524
# ACHN -1.060477 -0.212395 -0.490559  0.045988  0.047121 -0.039578 -0.003129
# ACLI  0.942972 -0.144048 -0.026249 -0.000528  0.048306 -0.059095  0.005731
#
#            S2'       S3'
# I1
# AATI  0.149560  0.203780
# ABPI  0.015851 -0.012833
# ACAD  0.012059 -0.011125
# ACHN  0.016015 -0.016718
# ACLI  0.016783 -0.012009
#
# [5 rows x 24 columns]

# %%
##Correlationi using .corr()
new_df.corr()
# Out:
#            P(IPO)      P(H)      P(L)   P(1Day)        C1        C2        C3  \
# P(IPO)   1.000000  0.867953  0.888556  0.038929  0.016603  0.218751  0.015709
# P(H)     0.867953  1.000000  0.990618  0.038671 -0.013412  0.188453  0.001585
# P(L)     0.888556  0.990618  1.000000  0.042100 -0.007560  0.205707  0.002475
# P(1Day)  0.038929  0.038671  0.042100  1.000000 -0.023288  0.034825 -0.131636
# C1       0.016603 -0.013412 -0.007560 -0.023288  1.000000 -0.017937  0.001916
# C2       0.218751  0.188453  0.205707  0.034825 -0.017937  1.000000  0.007315
# C3       0.015709  0.001585  0.002475 -0.131636  0.001916  0.007315  1.000000
# C4      -0.049557 -0.091464 -0.094337 -0.056249  0.034674 -0.050363  0.002999
# C5       0.376640  0.337514  0.348534 -0.007910  0.007371  0.128547 -0.000830
# C6       0.364109  0.317631  0.334299 -0.010152  0.008988  0.123738  0.010819
# C7       0.230273  0.218296  0.232358 -0.016819  0.030425  0.094346  0.006326
# Y1      -0.393505 -0.041870 -0.054794  0.023978  0.019316 -0.062170 -0.043933
# Y2      -0.020803 -0.111298 -0.119548  0.125543 -0.016552  0.069761 -0.065905
# C3'      0.145487  0.108916  0.118193 -0.055943  0.040107  0.010506  0.092113
# C5'      0.025422  0.037807  0.033204 -0.015538 -0.002450  0.053693 -0.002151
# C6'      0.228461 -0.085816 -0.054732  0.003288  0.106720  0.061434  0.001052
# T4'      0.001017  0.001809  0.000423  0.003630 -0.004381  0.093059  0.000882
# T3'      0.026482  0.016486  0.018341  0.004554  0.012208 -0.021421  0.000465
# T5'      0.030264  0.014454  0.022857 -0.001343 -0.012554  0.004102  0.000306
# S1'      0.028300  0.025321  0.030802 -0.000925 -0.004585 -0.018418 -0.000397
# S2'      0.031440  0.022089  0.030938  0.004846 -0.010605 -0.001378 -0.000603
# S3'      0.034182  0.028982  0.036869  0.001030 -0.009884  0.002241 -0.000462
#
#                C4        C5        C6    ...           Y2       C3'       C5'  \
# P(IPO)  -0.049557  0.376640  0.364109    ...    -0.020803  0.145487  0.025422
# P(H)    -0.091464  0.337514  0.317631    ...    -0.111298  0.108916  0.037807
# P(L)    -0.094337  0.348534  0.334299    ...    -0.119548  0.118193  0.033204
# P(1Day) -0.056249 -0.007910 -0.010152    ...     0.125543 -0.055943 -0.015538
# C1       0.034674  0.007371  0.008988    ...    -0.016552  0.040107 -0.002450
# C2      -0.050363  0.128547  0.123738    ...     0.069761  0.010506  0.053693
# C3       0.002999 -0.000830  0.010819    ...    -0.065905  0.092113 -0.002151
# C4       1.000000 -0.089836 -0.103205    ...     0.084033 -0.019777  0.016678
# C5      -0.089836  1.000000  0.881027    ...     0.020525  0.047558  0.091429
# C6      -0.103205  0.881027  1.000000    ...    -0.037274  0.032669 -0.051619
# C7      -0.004159  0.407184  0.395500    ...     0.015475  0.079704  0.078885
# Y1      -0.078876 -0.076970 -0.057917    ...    -0.227029 -0.083833 -0.024763
# Y2       0.084033  0.020525 -0.037274    ...     1.000000  0.018811  0.069573
# C3'     -0.019777  0.047558  0.032669    ...     0.018811  1.000000  0.025738
# C5'      0.016678  0.091429 -0.051619    ...     0.069573  0.025738  1.000000
# C6'      0.079987  0.051350  0.016240    ...     0.133568  0.008563  0.032197
# T4'     -0.007788  0.013468  0.007404    ...    -0.028746 -0.047843  0.015506
# T3'     -0.053360  0.015044  0.013715    ...    -0.031803 -0.037192  0.009378
# T5'     -0.011698  0.006015  0.006160    ...     0.017798 -0.052689  0.009206
# S1'     -0.059290  0.012467  0.011147    ...    -0.018393 -0.036403  0.009447
# S2'     -0.018016  0.005769  0.008258    ...    -0.000645 -0.063158  0.001942
# S3'     -0.029694  0.007086  0.010341    ...     0.003394 -0.047025 -0.006843
#
#               C6'       T4'       T3'       T5'       S1'       S2'       S3'
# P(IPO)   0.228461  0.001017  0.026482  0.030264  0.028300  0.031440  0.034182
# P(H)    -0.085816  0.001809  0.016486  0.014454  0.025321  0.022089  0.028982
# P(L)    -0.054732  0.000423  0.018341  0.022857  0.030802  0.030938  0.036869
# P(1Day)  0.003288  0.003630  0.004554 -0.001343 -0.000925  0.004846  0.001030
# C1       0.106720 -0.004381  0.012208 -0.012554 -0.004585 -0.010605 -0.009884
# C2       0.061434  0.093059 -0.021421  0.004102 -0.018418 -0.001378  0.002241
# C3       0.001052  0.000882  0.000465  0.000306 -0.000397 -0.000603 -0.000462
# C4       0.079987 -0.007788 -0.053360 -0.011698 -0.059290 -0.018016 -0.029694
# C5       0.051350  0.013468  0.015044  0.006015  0.012467  0.005769  0.007086
# C6       0.016240  0.007404  0.013715  0.006160  0.011147  0.008258  0.010341
# C7      -0.038512  0.007653  0.010307 -0.003680  0.012512 -0.006719  0.001201
# Y1      -0.503682  0.009023 -0.005424 -0.029367  0.006038 -0.020350 -0.003591
# Y2       0.133568 -0.028746 -0.031803  0.017798 -0.018393 -0.000645  0.003394
# C3'      0.008563 -0.047843 -0.037192 -0.052689 -0.036403 -0.063158 -0.047025
# C5'      0.032197  0.015506  0.009378  0.009206  0.009447  0.001942 -0.006843
# C6'      1.000000  0.007140  0.011479 -0.004687  0.001393 -0.010998 -0.011410
# T4'      0.007140  1.000000 -0.000133  0.009803  0.010894  0.004697  0.001419
# T3'      0.011479 -0.000133  1.000000  0.215583  0.592850  0.327513  0.393097
# T5'     -0.004687  0.009803  0.215583  1.000000  0.489413  0.898576  0.896548
# S1'      0.001393  0.010894  0.592850  0.489413  1.000000  0.714766  0.782049
# S2'     -0.010998  0.004697  0.327513  0.898576  0.714766  1.000000  0.935435
# S3'     -0.011410  0.001419  0.393097  0.896548  0.782049  0.935435  1.000000
#
# [22 rows x 22 columns]

# %%
# check if features are highly correlated with Target Variables using New_Df
##Y1 (>.5 or <-.5)

s1 = new_df.corr()['Y1'] > 0.5 
s2 = new_df.corr()['Y1'] < -0.5
s1 | s2 # logical OR
# Out:
# P(IPO)     False
# P(H)       False
# P(L)       False
# P(1Day)    False
# C1         False
# C2         False
# C3         False
# C4         False
# C5         False
# C6         False
# C7         False
# Y1          True
# Y2         False
# C3'        False
# C5'        False
# C6'         True
# T4'        False
# T3'        False
# T5'        False
# S1'        False
# S2'        False
# S3'        False
# Name: Y1, dtype: bool

# %%
# check if features are highly correlated with Target Variables using New_Df
##Y2 (>.5 or <-.5)

s1 = new_df.corr()['Y2'] > 0.5 
s2 = new_df.corr()['Y2'] < -0.5
s1 | s2 # logical OR
# Out:
# P(IPO)     False
# P(H)       False
# P(L)       False
# P(1Day)    False
# C1         False
# C2         False
# C3         False
# C4         False
# C5         False
# C6         False
# C7         False
# Y1         False
# Y2          True
# C3'        False
# C5'        False
# C6'        False
# T4'        False
# T3'        False
# T5'        False
# S1'        False
# S2'        False
# S3'        False
# Name: Y2, dtype: bool

# %%
###cannot include the C6' in Y1 essentially at the same, you cannot use any one to predict Y1 and Y2
## look at correlation between these things, create 2 versions in separapte models, filter method doesnt work..3 mthods for featur, filter method, recursive, imbeded
###wraper and imbeded
