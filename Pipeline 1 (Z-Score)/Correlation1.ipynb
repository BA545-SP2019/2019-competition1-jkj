# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
# %matplotlib inline
plt.style.use('ggplot')

# %%
# Creating DataFrame df from CSV StandDF
corr_df = pd.read_csv('Comp1', index_col=0)

# Displaying first five results 
corr_df.head()
# Out:
#      I1                                  I2    I3     P_IPO       P_H  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674 -0.657417 -1.536646
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834 -1.248445 -1.369829
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834 -1.602123 -0.201891
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834 -0.287236  0.299161
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  1.307714  1.391162
#
#         P_L    P_1DAY        C1        C2        C3    ...           S3  \
# 0 -1.353286 -0.448017  0.061864  0.397360  1.341329    ...     0.130419
# 1 -1.557354 -1.192796  1.363203 -2.516611 -0.868273    ...     1.496631
# 2 -0.192519 -1.306401 -0.464011  0.397360 -0.785803    ...    -2.020675
# 3  0.326368 -0.380307  0.992418  0.397360 -0.699081    ...    -0.468705
# 4  1.354312  2.359522 -0.667616  0.397360  0.438584    ...     0.600309
#
#         C3'       C5'       C6'       T4'       T3'       T5'       S1'  \
# 0  0.942972  0.073941  1.286365  1.015002  1.385100  2.581901  0.140345
# 1 -1.060477  2.663906 -0.769239  0.979116  1.016612  0.859650  0.170337
# 2 -1.060477 -0.238850 -0.769239  0.850319  0.988674  0.882630  0.009253
# 3 -1.060477 -0.286349 -0.769239  1.319898  0.944333  0.494001 -0.613426
# 4  0.942972 -0.009048  1.111842  0.629924  0.974235  0.760461  0.326324
#
#         S2'       S3'
# 0  2.443739  1.077346
# 1  0.935565  0.834546
# 2  1.166078  1.116250
# 3  1.081723  0.503971
# 4  1.366272  1.085523
#
# [5 rows x 24 columns]

# %%
#Calculate correlation with .corr(): 
print(corr_df.corr(method = 'spearman'))
# Out:
#               I3     P_IPO       P_H       P_L    P_1DAY        C1        C2  \
# I3      1.000000  0.094646 -0.008692 -0.008799  0.083463  0.047715 -0.044778
# P_IPO   0.094646  1.000000  0.786061  0.786237  0.682407 -0.063735  0.275398
# P_H    -0.008692  0.786061  1.000000  0.984833  0.459020 -0.049621  0.276393
# P_L    -0.008799  0.786237  0.984833  1.000000  0.472728 -0.049072  0.298192
# P_1DAY  0.083463  0.682407  0.459020  0.472728  1.000000 -0.040425  0.235805
# C1      0.047715 -0.063735 -0.049621 -0.049072 -0.040425  1.000000  0.005340
# C2     -0.044778  0.275398  0.276393  0.298192  0.235805  0.005340  1.000000
# C3      0.129757  0.183795  0.137152  0.158496  0.090679  0.054147  0.018299
# C4     -0.036350  0.004369 -0.021072 -0.032085 -0.006222  0.106729 -0.031415
# C5      0.009548  0.348061  0.354583  0.353167  0.239184  0.038375  0.432822
# C6     -0.031951  0.377693  0.431517  0.431884  0.207425  0.010487  0.401304
# S3'    -0.009318  0.030712 -0.078610    ...    -0.064204 -0.025866 -0.004783
#
#              C6'       T4'       T3'       T5'       S1'       S2'       S3'
# I3      0.102797  0.049887  0.033656  0.059568  0.036829  0.019920  0.124760
# P_IPO   0.497671 -0.044925  0.059958  0.025631  0.003774 -0.022016 -0.007460
# P_H     0.061825 -0.055122  0.014726 -0.025132 -0.026403 -0.030393 -0.046175
# P_L     0.052621 -0.058641  0.014657 -0.027820 -0.025395 -0.037220 -0.057652
# P_1DAY  0.474456 -0.048975  0.052287  0.008261  0.025908  0.005919 -0.005770
# C1     -0.049938 -0.037303 -0.003361 -0.022255  0.025511 -0.016744 -0.033430
# C2      0.114356  0.044132 -0.040508 -0.095588 -0.047322 -0.053052 -0.062514
# C3      0.119112 -0.004858  0.017013  0.060140 -0.009347 -0.029217 -0.009318
# C4      0.091373 -0.046287  0.029421  0.047207  0.044921  0.083379  0.030712
# C5      0.161956  0.034773  0.000851 -0.073021 -0.006477 -0.065905 -0.078610
# C6      0.095506 -0.012847 -0.013051 -0.064455 -0.018024 -0.068352 -0.084354
# C7     -0.005557 -0.048070  0.065897  0.017483  0.023068  0.002548 -0.028922
# S3      0.017075  0.006862  0.046828 -0.052697 -0.026956 -0.033077 -0.064204
# C3'     0.098919 -0.015078  0.023650  0.053604  0.004730 -0.037415 -0.025866
# C5'     0.126345  0.061783  0.034079 -0.020199  0.016937 -0.072248 -0.004783
# C6'     1.000000  0.012123  0.042500  0.072765  0.011410 -0.035645 -0.005337
# T4'     0.012123  1.000000 -0.000924 -0.027835  0.035314  0.064540 -0.019158
# T3'     0.042500 -0.000924  1.000000  0.441253  0.121319  0.101317  0.326137
# T5'     0.072765 -0.027835  0.441253  1.000000  0.073208  0.168846  0.367190
# S1'     0.011410  0.035314  0.121319  0.073208  1.000000  0.104943  0.143029
# S2'    -0.035645  0.064540  0.101317  0.168846  0.104943  1.000000  0.235896
# S3'    -0.005337 -0.019158  0.326137  0.367190  0.143029  0.235896  1.000000
#
# [22 rows x 22 columns]

# %%
# check if features are highly correlated with Target Variables using New_Df
##Y1 (>.5 or <-.5)

s1 = corr_df.corr()['Y1'] > 0.5 
s2 = corr_df.corr()['Y1'] < -0.5
s1 | s2 # logical OR
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Y1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-f05c956d6402> in <module>()
#       2 ##Y1 (>.5 or <-.5)
#       3
# ----> 4 s1 = corr_df.corr()['Y1'] > 0.5
#       5 s2 = corr_df.corr()['Y1'] < -0.5
#       6 s1 | s2 # logical OR
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Y1'
