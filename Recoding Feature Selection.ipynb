# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import seaborn as sns
from string import ascii_letters

# %%
stand_df = pd.read_csv('StandDF', index_col=0)
stand_df.head()
# Out:
#      I1                                  I2    I3    P(IPO)      P(H)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674 -0.636323 -0.905198
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834 -0.968157 -0.829439
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834 -1.134074 -0.223360
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834 -0.387448  0.079679
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  1.188763  0.837277
#
#        P(L)   P(1Day)        C1        C2        C3    ...          C3'  \
# 0 -0.865043 -0.190333 -0.175193  0.397360  0.010968    ...     0.942972
# 1 -0.951417 -0.254485  0.735662 -2.516611 -0.020955    ...    -1.060477
# 2 -0.260419 -0.262122 -0.387947  0.397360 -0.018553    ...    -1.060477
# 3  0.085080 -0.183112  0.403233  0.397360 -0.016467    ...    -1.060477
# 4  0.948829  0.430778 -0.454433  0.397360 -0.010272    ...     0.942972
#
#         C5'    P(mid)       C6'       T4'       T3'       T5'       S1'  \
# ...

# %%
#convert the DataFrame object to a NumPy array to achieve faster computation. 
##Also, let's segregate the data into separate 
##variables so that the features and the labels are separated.
array = stand_df.values
X = array[:,0:34] #features
Y = array[:,2] #target

# %%
# Import the necessary libraries first
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
# Feature extraction
test = SelectKBest(score_func=chi2, k=4)
fit = test.fit(X, Y)

# Summarize scores
np.set_printoptions(precision=3)
print(fit.scores_)

features = fit.transform(X)
# Summarize selected features
print(features[0:5,:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-f060238d2c40> in <module>()
#       1 # Feature extraction
#       2 test = SelectKBest(score_func=chi2, k=4)
# ----> 3 fit = test.fit(X, Y)
#       4
#       5 # Summarize scores
#
# /opt/tljh/user/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py in fit(self, X, y)
#     339             Returns self.
#     340         """
# --> 341         X, y = check_X_y(X, y, ['csr', 'csc'], multi_output=True)
#     342
#     343         if not callable(self.score_func):
#
# /opt/tljh/user/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...
